# %% [markdown]
# ThinkDSP, by Allen Downey
# (think-dsp.com)
#
# This notebook contains code examples from Chapter 8: Filtering and convolution

# %%
import thinkdsp
import thinkplot
import thinkstats2
import math
import numpy
import pandas
import scipy.signal

from __future__ import print_function, division

# %%
signal = thinkdsp.SquareSignal(freq=440)
signal.plot()

# %%
wave = signal.make_wave(duration=1, framerate=44100)
wave.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
hs = scipy.fftpack.fft(wave.ys)
thinkplot.plot(numpy.absolute(hs))
len(wave.ys), len(hs)
# Out:
# (44100, 44100)

# %%
n = len(hs)//2
rolled = numpy.roll(hs, n)
thinkplot.plot(numpy.absolute(rolled))

# %%
thinkplot.plot(numpy.angle(hs[:100]))

# %%
window = scipy.signal.gaussian(9, 3)
window /= sum(window)
window
# Out:
# array([ 0.0629702 ,  0.0929025 ,  0.12264921,  0.14489292,  0.15317033,
#         0.14489292,  0.12264921,  0.0929025 ,  0.0629702 ])

# %%
thinkplot.plot(window)

# %%
segment = wave.segment(duration=0.01)
n = len(window)
padded = numpy.zeros_like(segment.ys)
padded[:n] = window
thinkplot.plot(padded)
thinkplot.plot(segment.ys)

# %%
prod = padded * segment.ys
sum(prod)
# Out:
# -1.0

# %%
convolved = numpy.zeros_like(segment.ys)
rolled = padded
for i in range(len(segment.ys)):
    convolved[i] = sum(rolled * segment.ys)
    rolled = numpy.roll(rolled, 1)

# %%
smooth = thinkdsp.Wave(convolved, framerate=wave.framerate)
wave.segment(duration=0.01).plot(color='gray')
smooth.segment(duration=0.01).plot()

# %%
ys = scipy.signal.convolve(wave.ys, window, mode='valid')
smooth = thinkdsp.Wave(ys, framerate=wave.framerate)

wave.segment(duration=0.01).plot(color='gray')
smooth.segment(duration=0.01).plot()

# %%
smooth.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
wave.make_spectrum().plot(color='gray')
smooth.make_spectrum().plot()

# %%
amps = wave.make_spectrum().amps
amps2 = smooth.make_spectrum().amps

n = min(len(amps), len(amps2))
ratio = amps2[:n] / amps[:n]

thinkplot.plot(ratio)

# %%
n = len(window)
padded = numpy.zeros_like(wave.ys)
padded[:n] = window
fft_window = scipy.fftpack.fft(padded)
thinkplot.plot(ratio/450)
thinkplot.plot(abs(fft_window)[:22050])

# %%
hs = scipy.fftpack.fft(padded) * scipy.fftpack.fft(wave.ys)
thinkplot.plot(abs(hs)[:22050])

# %%
ys = scipy.fftpack.ifft(hs)
wave2 = thinkdsp.Wave(ys.real, framerate=wave.framerate)
wave2.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
wave.segment(duration=0.01).plot(color='gray')
wave2.segment(duration=0.01).plot()

# %%
# note: using skipfooter would be better than nrows, but not currently supported
df = pandas.read_csv('coindesk-bpi-USD-close.csv', nrows=1585, parse_dates=[0])
df
# Out:
#            Date     Close
# 0    2010-07-18    0.0858
# 1    2010-07-19    0.0808
# 2    2010-07-20    0.0747
# 3    2010-07-21    0.0792
# 4    2010-07-22    0.0505
# 5    2010-07-23    0.0626
# 6    2010-07-24    0.0545
# 7    2010-07-25    0.0505
# 8    2010-07-26    0.0560
# 9    2010-07-27    0.0600
# 10   2010-07-28    0.0589
# 11   2010-07-29    0.0699
# 12   2010-07-30    0.0627
# 13   2010-07-31    0.0679
# 14   2010-08-01    0.0611
# 15   2010-08-02    0.0600
# 16   2010-08-03    0.0600
# 17   2010-08-04    0.0570
# 18   2010-08-05    0.0610
# 19   2010-08-06    0.0623
# 20   2010-08-07    0.0590
# 21   2010-08-08    0.0609
# 22   2010-08-09    0.0710
# 23   2010-08-10    0.0700
# 24   2010-08-11    0.0670
# 25   2010-08-12    0.0700
# 26   2010-08-13    0.0645
# 27   2010-08-14    0.0670
# 28   2010-08-15    0.0653
# 29   2010-08-16    0.0655
# ...         ...       ...
# 1555 2014-10-20  379.3713
# 1556 2014-10-21  382.3770
# 1557 2014-10-22  379.0963
# ...

# %%
ys = df.Close.values
wave = thinkdsp.Wave(ys, framerate=1)
wave.plot()

# %%
spectrum = wave.make_spectrum()
spectrum.plot()
thinkplot.config(xscale='log', yscale='log', legend=False)

# %%
spectrum.estimate_slope()
# Out:
# (-1.8427491989246421,
#  9.7682377707713037,
#  -0.81413693815309618,
#  1.1167571724295024e-188,
#  0.046761324362981541)

# %%
diff = numpy.diff(ys)
wave2 = thinkdsp.Wave(diff, framerate=1)
wave2.plot()

# %%
spectrum2 = wave2.make_spectrum()
spectrum2.plot()

# %%
peaks = spectrum2.peaks()
peaks[:10]
# Out:
# [(2194.1012965884706, 0.19128787878787881),
#  (2170.3367973194331, 0.19191919191919193),
#  (2154.0525787187762, 0.18813131313131315),
#  (2119.8929979038817, 0.18876262626262627),
#  (1974.1651841470957, 0.18939393939393942),
#  (1937.1331669888893, 0.18750000000000003),
#  (1930.2921862061892, 0.19065656565656566),
#  (1873.1809518453204, 0.19002525252525254),
#  (1770.64841210485, 0.19255050505050506),
#  (1755.0687997835407, 0.18686868686868688)]

# %%
1 / peaks[0][1]
# Out:
# 5.227722772277227

# %%
amps = spectrum.amps
amps2 = spectrum2.amps

n = min(len(amps), len(amps2))
ratio = amps2[:n] / amps[:n]

thinkplot.plot(ratio)

# %%
window = numpy.array([-1.0, 1.0])

# uncomment this line to try a higher-order estimate of the derivative
# window = numpy.array([-1.0, 8.0, -8.0, 1.0]) / 12.0

# %%
ys = scipy.signal.convolve(wave.ys, window, mode='valid')
diff = thinkdsp.Wave(ys, framerate=1)
diff.plot()

# %%
n = len(window)
padded = numpy.zeros_like(wave.ys)
padded[:n] = window

# %%
fft_window = scipy.fftpack.fft(padded)
n = len(fft_window)

thinkplot.plot(abs(fft_window)[:n/2])

# %%
thinkplot.plot(ratio, color='gray')
thinkplot.plot(abs(fft_window)[:n/2])

# %%
fft_wave = scipy.fftpack.fft(wave.ys)
prod = fft_window * fft_wave
thinkplot.plot(abs(prod))

# %%
ys = scipy.fftpack.ifft(prod)
diff.plot(color='gray')
thinkplot.plot(ys)
# Out:
# /home/downey/anaconda/lib/python2.7/site-packages/numpy/core/numeric.py:462: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
fft_integration_window = 1 / fft_window
thinkplot.plot(abs(fft_integration_window)[:n/2])
# thinkplot.config(xscale='log', yscale='log', legend=False)

# %%
fft_integration_window[0] = 0

# %%
integration_window = scipy.fftpack.ifft(fft_integration_window)
integration_window
# Out:
# array([-0.49968454 +6.79442482e-18j, -0.49905363 +6.19903708e-17j,
#        -0.49842271 -1.01916372e-17j, ...,  0.49842271 -2.23875346e-17j,
#         0.49905363 -1.25954385e-17j,  0.49968454 +3.36734362e-17j])

# %%
thinkplot.plot(integration_window.real)
