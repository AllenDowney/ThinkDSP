# %% [markdown]
# ThinkDSP, by Allen Downey
# (think-dsp.com)
#
# This notebook contains code examples from Chapter 8: Filtering and convolution

# %%
from __future__ import print_function, division

import thinkdsp
import thinkplot
import thinkstats2
import math
import numpy
import pandas
import scipy.signal

# %precision 3
# %matplotlib inline

PI2 = 2 * math.pi

# %%
nrows = 1625
df = pandas.read_csv('coindesk-bpi-USD-close.csv', nrows=nrows, parse_dates=[0])

# %%
ys = df.Close.values
diff = numpy.diff(ys)
changes = 100 * diff / ys[:len(diff)]

# %%
window = numpy.ones(30)
window /= sum(window)
smoothed = numpy.convolve(changes, window, mode='same')

# %%
thinkplot.preplot(1)
thinkplot.plot(changes, color='0.7', label='daily')
thinkplot.plot(smoothed, label='30 day average')
thinkplot.config(xlabel='time (days)', 
                 ylabel='% change',
                 xlim=[0, nrows],
                 ylim=[-60, 60],
                 loc='lower right')

# %%
signal = thinkdsp.SquareSignal(freq=440)
wave = signal.make_wave(duration=1, framerate=44100)
wave.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
window = numpy.ones(11)
window /= sum(window)
thinkplot.plot(window)

# %%
segment = wave.segment(duration=0.01)
segment.plot()
thinkplot.config(ylim=[-1.05, 1.05])

# %%
padded = numpy.zeros_like(segment.ys)
padded[:len(window)] = window

thinkplot.plot(padded)

# %%
prod = padded * segment.ys
print(sum(prod))
# Out:
# -1.0

# %%
smoothed = numpy.zeros_like(segment.ys)
rolled = padded
for i in range(len(segment.ys)):
    smoothed[i] = sum(rolled * segment.ys)
    rolled = numpy.roll(rolled, 1)

# %%
segment.plot(color='0.7')
smooth = thinkdsp.Wave(smoothed, framerate=wave.framerate)
smooth.plot()
thinkplot.config(ylim=[-1.05, 1.05], legend=False)

# %%
segment.plot(color='0.7')
ys = numpy.convolve(segment.ys, window, mode='valid')
smooth2 = thinkdsp.Wave(ys, framerate=wave.framerate)
smooth2.plot()
thinkplot.config(ylim=[-1.05, 1.05], legend=False)

# %%
spectrum = wave.make_spectrum()

# %%
ys = numpy.convolve(wave.ys, window, mode='same')
smooth = thinkdsp.Wave(ys, framerate=wave.framerate)
spectrum2 = smooth.make_spectrum()

# %%
thinkplot.preplot(1)
spectrum2.plot()
spectrum.plot(color='0.7')

# %%
amps = spectrum.amps
amps2 = spectrum2.amps
ratio = amps2 / amps    
ratio[amps<560] = 0
thinkplot.plot(ratio)

thinkplot.config(xlabel='frequency (Hz)',
                     ylabel='amplitude ratio',
                     xlim=[0, 22050], 
                     legend=False)

# %%
padded = numpy.zeros_like(wave.ys)
padded[:len(window)] = window
dft_window = numpy.fft.rfft(padded)

thinkplot.plot(abs(dft_window), color='0.7', label='boxcar filter')
thinkplot.plot(ratio, label='amplitude ratio')

thinkplot.config(xlabel='frequency (Hz)',
                     ylabel='amplitude ratio',
                     xlim=[0, 22050], 
                     legend=False)

# %%
signal = thinkdsp.SquareSignal(freq=440)
wave = signal.make_wave(duration=1, framerate=44100)
spectrum = wave.make_spectrum()

# %%
boxcar = numpy.ones(11)
boxcar /= sum(boxcar)

# %%
gaussian = scipy.signal.gaussian(M=11, std=2)
gaussian /= sum(gaussian)

# %%
thinkplot.preplot(2)
thinkplot.plot(boxcar, label='boxcar')
thinkplot.plot(gaussian, label='Gaussian')
thinkplot.config(xlabel='index',
                 ylabel='amplitude')

# %%
ys = numpy.convolve(wave.ys, gaussian, mode='same')
smooth = thinkdsp.Wave(ys, framerate=wave.framerate)
spectrum2 = smooth.make_spectrum()

# %%
amps = spectrum.amps
amps2 = spectrum2.amps
ratio = amps2 / amps    
ratio[amps<560] = 0

# %%
padded = numpy.zeros_like(wave.ys)
padded[:len(gaussian)] = gaussian
dft_gaussian = numpy.fft.rfft(padded)

# %%
thinkplot.plot(abs(dft_gaussian), color='0.7', label='Gaussian filter')
thinkplot.plot(ratio, label='amplitude ratio')

thinkplot.config(xlabel='frequency (Hz)',
                 ylabel='amplitude ratio',
                 xlim=[0, 22050], 
                 legend=False)

# %%
def plot_filter(M=11, std=2):
    signal = thinkdsp.SquareSignal(freq=440)
    wave = signal.make_wave(duration=1, framerate=44100)
    spectrum = wave.make_spectrum()

    gaussian = scipy.signal.gaussian(M=M, std=std)
    gaussian /= sum(gaussian)

    ys = numpy.convolve(wave.ys, gaussian, mode='same')
    smooth = thinkdsp.Wave(ys, framerate=wave.framerate)
    spectrum2 = smooth.make_spectrum()

    # plot the ratio of the original and smoothed spectrum
    amps = spectrum.amps
    amps2 = spectrum2.amps
    ratio = amps2 / amps    
    ratio[amps<560] = 0

    # plot the same ratio along with the FFT of the window
    padded = numpy.zeros_like(wave.ys)
    padded[:len(gaussian)] = gaussian
    dft_gaussian = numpy.fft.rfft(padded)

    thinkplot.plot(abs(dft_gaussian), color='0.7', label='Gaussian filter')
    thinkplot.plot(ratio, label='amplitude ratio')

    thinkplot.config(xlabel='frequency (Hz)',
                     ylabel='amplitude ratio',
                     xlim=[0, 22050],
                     ylim=[0, 1.05],
                     legend=False)

# %%
from IPython.html.widgets import interact, fixed
from IPython.html import widgets

slider = widgets.IntSliderWidget(min=2, max=100, value=11)
slider2 = widgets.FloatSliderWidget(min=0, max=20, value=2)
interact(plot_filter, M=slider, std=slider2)
None

# %%
ys = df.Close.values
window = scipy.signal.gaussian(M=30, std=6)
window /= window.sum()
smoothed = numpy.convolve(ys, window, mode='valid')

# %%
thinkplot.plot(ys, color='0.7')
thinkplot.plot(smoothed)

# %%
padded = numpy.zeros_like(ys)
padded[:len(window)] = window
fft_window = numpy.fft.fft(padded)
thinkplot.plot(numpy.absolute(fft_window))

# %%
fft_signal = numpy.fft.fft(ys)
smoothed2 = numpy.fft.ifft(fft_signal * fft_window)

# %%
thinkplot.plot(smoothed)
thinkplot.plot(smoothed2[29:])

# %%
diff = smoothed - smoothed2[29:]
sum(abs(diff))
# Out:
# 0.000

# %%
smoothed3 = scipy.signal.fftconvolve(ys, window, mode='valid')

# %%
diff = smoothed - smoothed3
sum(abs(diff))
# Out:
# 0.000

# %%
def convolve(signal, window):
    M = len(window)    
    padded = numpy.zeros_like(signal)
    padded[:M] = window
    fft_window = numpy.fft.fft(padded)
    fft_signal = numpy.fft.fft(signal)
    smoothed = numpy.fft.ifft(fft_signal * fft_window)
    return smoothed

# %%
M = len(window)
smoothed4 = convolve(ys, window)[M-1:]
diff = smoothed - smoothed4
sum(abs(diff))
# Out:
# 0.000

# %%
ys = df.Close.values
diff = numpy.diff(ys)
changes = 100 * diff / ys[:len(diff)]

# %%
signal = ys
N = len(signal)
corrs = numpy.correlate(signal, signal, mode='same')
thinkplot.plot(corrs)
corrs[:10]
# Out:
# array([-20186161.789, -20164670.063, -20142992.411, -20120797.664,
#        -20097733.245, -20074416.865, -20051108.008, -20027856.058,
#        -20004185.433, -19980027.598])

# %%
def fft_autocorr(signal):
    N = len(signal)
    window = signal[::-1]
    
    #M = len(window)    
    #padded = numpy.zeros_like(signal)
    #padded[:M] = window
    fft_window = numpy.fft.fft(window)
    fft_signal = numpy.fft.fft(signal)
    corrs = numpy.fft.ifft(fft_signal * fft_window)
    corrs = numpy.roll(corrs, N//2)
    return corrs.real

# %%
thinkplot.plot(signal)
thinkplot.plot(signal[::-1])

# %%
N = len(signal)
corrs2 = fft_autocorr(signal)
thinkplot.plot(corrs)
thinkplot.plot(corrs2)

# %%
print(len(corrs), len(corrs2))
# Out:
# 1624 1624

# %%
diff = corrs - corrs2
sum(abs(diff))
thinkplot.plot(diff)
