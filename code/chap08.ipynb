# %% [markdown]
# ThinkDSP, by Allen Downey
# (think-dsp.com)
#
# This notebook contains code examples from Chapter 8: Filtering and convolution

# %%
import thinkdsp
import thinkplot
import thinkstats2
import math
import numpy
import pandas
import scipy.signal

from __future__ import print_function, division

# %% [markdown]
# Until now we've been using Wave.make_spectrum, which uses scipy.fftpack.rfft.  The `r` stands for real, which takes advantage of the fact that the signal is real-valued (because everything we measure in the world is real-valued).
#
# Given N samples, rfft returns N/2 complex number, each one encoding the amplitude and phase offset of a frequency component.
#
# Now we're going to switch to the fft, which takes a vector of complex and returns a vector of complex with the same length.
#
# As an example, I'll compute the spectrum of a square wave.

# %%
signal = thinkdsp.SquareSignal(freq=440)
signal.plot()

# %% [markdown]
# Make a 1-second wave.

# %%
wave = signal.make_wave(duration=1, framerate=44100)
wave.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Using scipy.fftpack.fft, the spectrum looks different:

# %%
hs = scipy.fftpack.fft(wave.ys)
thinkplot.plot(numpy.absolute(hs))
len(wave.ys), len(hs)
# Out:
# (44100, 44100)

# %% [markdown]
# The first half of the spectrum is what we have seen before using `rfft`.  The second half corresponds to "negative frequencies".  The fact that the negative frequencies appear on the right is a consequence of the way FFT is computed.  To display the results, it is helpful to `roll` the array so the negatives are on the left.

# %%
n = len(hs)//2
rolled = numpy.roll(hs, n)
thinkplot.plot(numpy.absolute(rolled))

# %% [markdown]
# For a real-valued signal, the spectrum is always symmetric.

# %% [markdown]
# The next idea to consider is convolution.  To motivate convolution, let me start with smoothing.  Suppose you have a signal, like a square wave, with a lot of energy at high frequencies.  One way to smooth out the high frequencies is to compute something like a local average, where you replace each point in the wave with a weighted sum of its neighbors.
#
# One form of smoothing is a Gaussian window, which computes a weighted sum with weights from a Gaussian curve.  `scipy.signal` provides `gaussian`, which computes the weights of a Gaussian window.

# %%
window = scipy.signal.gaussian(9, 3)
window /= sum(window)
window
# Out:
# array([ 0.0629702 ,  0.0929025 ,  0.12264921,  0.14489292,  0.15317033,
#         0.14489292,  0.12264921,  0.0929025 ,  0.0629702 ])

# %% [markdown]
# Sure enough, the weights look like a "Bell curve", but truncated.

# %%
thinkplot.plot(window)

# %% [markdown]
# If we pad the window so it has the same length as the wave, we can plot the window on top of the wave.

# %%
segment = wave.segment(duration=0.01)
n = len(window)
padded = numpy.zeros_like(segment.ys)
padded[:n] = window
thinkplot.plot(padded)
print(padded[:n+4])
thinkplot.plot(segment.ys)
# Out:
# [ 0.0629702   0.0929025   0.12264921  0.14489292  0.15317033  0.14489292
#   0.12264921  0.0929025   0.0629702   0.          0.          0.          0.        ]
# ...

# %% [markdown]
# If we multiply the window and the wave, we get the first point in the smoothed signal.

# %%
prod = padded * segment.ys
sum(prod)
# Out:
# -1.0

# %% [markdown]
# Now we can shift the window to the next location and repeat, computing a smoothed wave:

# %%
convolved = numpy.zeros_like(segment.ys)
rolled = padded
for i in range(len(segment.ys)):
    convolved[i] = sum(rolled * segment.ys)
    rolled = numpy.roll(rolled, 1)

# %% [markdown]
# Here's the result, plotted on top of the original wave.

# %%
wave.segment(duration=0.01).plot(color='gray')

smooth = thinkdsp.Wave(convolved, framerate=wave.framerate)
smooth.segment(duration=0.01).plot()

# %% [markdown]
# Smoothing makes the square wave ramp up more slowly, and rounds off the corners a little.
#
# This process -- applying a window to each point of a wave and computing the product -- is called convolution.  The implementation we just saw is not very efficient, but `scipy.signal` provides a better implementation:

# %%
ys = scipy.signal.convolve(wave.ys, window, mode='same')
smooth = thinkdsp.Wave(ys, framerate=wave.framerate)

wave.segment(duration=0.01).plot(color='gray')
smooth.segment(duration=0.01).plot()

# %% [markdown]
# The results are similar, although `convolve` starts with the window in a different location, so the result is shifted (compared to my implementation).

# %%
smooth.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Smoothing makes the sound a little less "buzzy".
#
# We can see this effect by comparing the spectrums:

# %%
#wave.ys = wave.ys[:len(smooth)]
wave.make_spectrum().plot(color='gray')
smooth.make_spectrum().plot()

# %%
wave.make_spectrum().amps[440]
# Out:
# 27778.614712334977

# %%
smooth.make_spectrum().amps[440]
# Out:
# 27508.940993253498

# %% [markdown]
# Smoothing is a low-pass filter; it attenuates high frequencies much more than lower ones.
#
# To quantify that effect, we can compute the ratio of the amplitudes at each frequency, before and after smoothing:

# %%
amps = wave.make_spectrum().amps
amps2 = smooth.make_spectrum().amps

n = len(amps2)
amps = amps[:n]
ratio = amps2 / amps

ratio[amps<500] = 0

thinkplot.plot(ratio)

# %% [markdown]
# It looks like there is some structure to those ratios, and the convolution theorem tells us what that structure is.  Convolution with a window in the time domain has the effect of multiplying the spectrum by a filter, and the shape of the filter is the DFT of the window:

# %%
n = len(window)
padded = numpy.zeros_like(wave.ys)
padded[:n] = window
fft_window = scipy.fftpack.fft(padded)
thinkplot.plot(ratio)
thinkplot.plot(abs(fft_window)[:22050])

# %%
hs = scipy.fftpack.fft(padded) * scipy.fftpack.fft(wave.ys)
thinkplot.plot(abs(hs)[:22050])

# %%
ys = scipy.fftpack.ifft(hs)
wave2 = thinkdsp.Wave(ys.real, framerate=wave.framerate)
wave2.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
wave.segment(duration=0.01).plot(color='gray')
wave2.segment(duration=0.01).plot()

# %%
# note: using skipfooter would be better than nrows, but not currently supported
df = pandas.read_csv('coindesk-bpi-USD-close.csv', nrows=1585, parse_dates=[0])
df
# Out:
#            Date     Close
# 0    2010-07-18    0.0858
# 1    2010-07-19    0.0808
# 2    2010-07-20    0.0747
# 3    2010-07-21    0.0792
# 4    2010-07-22    0.0505
# 5    2010-07-23    0.0626
# 6    2010-07-24    0.0545
# 7    2010-07-25    0.0505
# 8    2010-07-26    0.0560
# 9    2010-07-27    0.0600
# 10   2010-07-28    0.0589
# 11   2010-07-29    0.0699
# 12   2010-07-30    0.0627
# 13   2010-07-31    0.0679
# 14   2010-08-01    0.0611
# 15   2010-08-02    0.0600
# 16   2010-08-03    0.0600
# 17   2010-08-04    0.0570
# 18   2010-08-05    0.0610
# 19   2010-08-06    0.0623
# 20   2010-08-07    0.0590
# 21   2010-08-08    0.0609
# 22   2010-08-09    0.0710
# 23   2010-08-10    0.0700
# 24   2010-08-11    0.0670
# 25   2010-08-12    0.0700
# 26   2010-08-13    0.0645
# 27   2010-08-14    0.0670
# 28   2010-08-15    0.0653
# 29   2010-08-16    0.0655
# ...         ...       ...
# 1555 2014-10-20  379.3713
# 1556 2014-10-21  382.3770
# 1557 2014-10-22  379.0963
# ...

# %%
ys = df.Close.values
wave = thinkdsp.Wave(ys, framerate=1)
wave.plot()

# %%
spectrum = wave.make_spectrum()
spectrum.plot()
thinkplot.config(xscale='log', yscale='log', legend=False)

# %%
spectrum.estimate_slope()
# Out:
# (-1.8427491989246421,
#  9.7682377707713037,
#  -0.81413693815309618,
#  1.1167571724295024e-188,
#  0.046761324362981541)

# %%
diff = numpy.diff(ys)
wave2 = thinkdsp.Wave(diff, framerate=1)
wave2.plot()

# %%
spectrum2 = wave2.make_spectrum()
spectrum2.plot()

# %%
peaks = spectrum2.peaks()
peaks[:10]
# Out:
# [(2194.1012965884706, 0.19128787878787881),
#  (2170.3367973194331, 0.19191919191919193),
#  (2154.0525787187762, 0.18813131313131315),
#  (2119.8929979038817, 0.18876262626262627),
#  (1974.1651841470957, 0.18939393939393942),
#  (1937.1331669888893, 0.18750000000000003),
#  (1930.2921862061892, 0.19065656565656566),
#  (1873.1809518453204, 0.19002525252525254),
#  (1770.64841210485, 0.19255050505050506),
#  (1755.0687997835407, 0.18686868686868688)]

# %%
1 / peaks[0][1]
# Out:
# 5.227722772277227

# %%
amps = spectrum.amps
amps2 = spectrum2.amps

n = min(len(amps), len(amps2))
ratio = amps2[:n] / amps[:n]

thinkplot.plot(ratio)

# %%
window = numpy.array([-1.0, 1.0])

# uncomment this line to try a higher-order estimate of the derivative
# window = numpy.array([-1.0, 8.0, -8.0, 1.0]) / 12.0

# %%
ys = scipy.signal.convolve(wave.ys, window, mode='valid')
diff = thinkdsp.Wave(ys, framerate=1)
diff.plot()

# %%
n = len(window)
padded = numpy.zeros_like(wave.ys)
padded[:n] = window

# %%
fft_window = scipy.fftpack.fft(padded)
n = len(fft_window)

thinkplot.plot(abs(fft_window)[:n/2])

# %%
thinkplot.plot(ratio, color='gray')
thinkplot.plot(abs(fft_window)[:n/2])

# %%
fft_wave = scipy.fftpack.fft(wave.ys)
prod = fft_window * fft_wave
thinkplot.plot(abs(prod))

# %%
ys = scipy.fftpack.ifft(prod)
diff.plot(color='gray')
thinkplot.plot(ys)
# Out:
# /home/downey/anaconda/lib/python2.7/site-packages/numpy/core/numeric.py:462: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
fft_integration_window = 1 / fft_window
thinkplot.plot(abs(fft_integration_window)[:n/2])
# thinkplot.config(xscale='log', yscale='log', legend=False)

# %%
fft_integration_window[0] = 0

# %%
integration_window = scipy.fftpack.ifft(fft_integration_window)
integration_window
# Out:
# array([-0.49968454 +6.79442482e-18j, -0.49905363 +6.19903708e-17j,
#        -0.49842271 -1.01916372e-17j, ...,  0.49842271 -2.23875346e-17j,
#         0.49905363 -1.25954385e-17j,  0.49968454 +3.36734362e-17j])

# %%
thinkplot.plot(integration_window.real)

# %%
diff.plot()
# Out:
# 1584

# %%
ys = scipy.signal.convolve(ys, integration_window, mode='valid')
integral = thinkdsp.Wave(ys, framerate=1)
integral.plot()
integral
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-815738246513> in <module>()
# ----> 1 ys = scipy.signal.convolve(ys, integration_window, mode='valid')
#       2 integral = thinkdsp.Wave(ys, framerate=1)
#       3 integral.plot()
#       4 integral
#
# /home/downey/anaconda/lib/python2.7/site-packages/scipy/signal/signaltools.pyc in convolve(in1, in2, mode)
#     330
#     331     if np.iscomplexobj(kernel):
# --> 332         return correlate(volume, kernel[slice_obj].conj(), mode)
#     333     else:
#     334         return correlate(volume, kernel[slice_obj], mode)
#
# /home/downey/anaconda/lib/python2.7/site-packages/scipy/signal/signaltools.pyc in correlate(in1, in2, mode)
#     126
#     127     if mode == 'valid':
# --> 128         _check_valid_mode_shapes(in1.shape, in2.shape)
#     129         ps = [i - j + 1 for i, j in zip(in1.shape, in2.shape)]
# ...

# %%
len(diff), len(integration_window)
# Out:
# (1584, 1585)
