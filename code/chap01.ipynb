# %% [markdown]
# ThinkDSP, by Allen Downey
#
# This notebook contains code examples from Chapter 1: Sounds and Signals

# %% [markdown]
# `thinkdsp` is a module that accompanies ThinkDSP and provides classes and functions for working with signals.
#
# `thinkplot` is a wrapper around matplotlib.

# %%
import thinkdsp
import thinkplot

# %% [markdown]
# Instantiate cosine and sine signals.

# %%
cos_sig = thinkdsp.CosSignal(freq=440, amp=1.0, offset=0)
sin_sig = thinkdsp.SinSignal(freq=880, amp=0.5, offset=0)

# %% [markdown]
# Plot three periods from each signal.

# %%
cos_sig.plot()

# %%
sin_sig.plot()

# %% [markdown]
# The sum of two signals is a SumSignal.

# %%
mix = sin_sig + cos_sig
mix

# %% [markdown]
# A Signal represents a mathematical function defined for all values of time.  If you evaluate a signal at a sequence of equally-spaced times, the result is a Wave.  `framerate` is the number of samples per second.

# %%
wave = mix.make_wave(duration=0.5, start=0, framerate=11025)
wave

# %% [markdown]
# IPython provides an Audio widget that can play a wave.

# %%
from IPython.display import Audio
audio = Audio(data=wave.ys, rate=wave.framerate)
audio
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Wave also provides `make_audio()`, which does the same thing:

# %%
wave.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# The `ys` attribute is a NumPy array that contains the values from the signal.  The interval between samples is the inverse of the framerate.

# %%
print 'Number of samples', len(wave.ys)
print 'Timestep in ms', 1.0 / wave.framerate * 1000
# Out:
# Number of samples 5513
# Timestep in ms 0.0907029478458

# %% [markdown]
# Signal objects that represent periodic signals have a `period` attribute.  Wave provides `segment`, which creates a new wave.

# %%
period = mix.period
segment = wave.segment(start=0, duration=period*3)

# %% [markdown]
# Wave provides `plot`

# %%
segment.plot()

# %% [markdown]
# `normalize` scales a wave so the range doesn't exceed -1 to 1.
#
# `apodize` tapers the beginning and end of the wave so it doesn't click when you play it.

# %%
wave.normalize()
wave.apodize()
wave.plot()

# %% [markdown]
# You can write a wave to a WAV file.

# %%
filename = 'temp.wav'
wave.write('temp.wav')
# Out:
# Writing temp.wav

# %% [markdown]
# `play_wave` writes the wave to a file and then uses an exernal player.

# %%
thinkdsp.play_wave(filename='temp.wav', player='aplay')

# %% [markdown]
# `read_wave` reads WAV files.  The WAV examples in the book are from freesound.org.

# %%
 wave = thinkdsp.read_wave('92002__jcveliz__violin-origional.wav')

# %% [markdown]
# I pulled out a segment of this recording where the pitch is constant

# %%
start = 1.2
duration = 0.6
segment = wave.segment(start, duration)

# %% [markdown]
# `make_spectrum` computes the spectrum of the wave.

# %%
spectrum = segment.make_spectrum()

# %% [markdown]
# Spectrum provides `plot`

# %%
spectrum.plot()

# %%
spectrum.low_pass(1800)

# %%
spectrum.plot()

# %%
filtered = spectrum.make_wave()
filtered.plot()

# %%
filtered.normalize()
filtered.plot()

# %%
segment.apodize()
segment.plot()

# %%
filtered.apodize()
filtered.plot()

# %%
segment.make_audio()

# %%
filtered.make_audio()
